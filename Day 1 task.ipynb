# %%
import pandas as pd
file_path = "/content/Mall_Customers.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df_info = df.info()
df_summary = {
    "shape": df.shape,
    "null_values": df.isnull().sum(),
    "duplicates": df.duplicated().sum(),
    "dtypes": df.dtypes
}
df_summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# {'shape': (200, 5),
#  'null_values': CustomerID                0
#  Gender                    0
#  Age                       0
#  Annual Income (k$)        0
#  Spending Score (1-100)    0
#  dtype: int64,
#  'duplicates': np.int64(0),
#  'dtypes': CustomerID                 int64
#  Gender                    object
#  Age                        int64
#  Annual Income (k$)         int64
#  Spending Score (1-100)     int64
#  dtype: object}

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(r'[\s\(\)\-]+', '_', regex=True)
df['gender'] = df['gender'].str.capitalize()
df.head()
# Out:
#    customerid  gender  age  annual_income_k$_  spending_score_1_100_
# 0           1    Male   19                 15                     39
# 1           2    Male   21                 15                     81
# 2           3  Female   20                 16                      6
# 3           4  Female   23                 16                     77
# 4           5  Female   31                 17                     40

# %%
cleaned_path = "/content/Mall_Customers_Cleaned.csv"
df.to_csv(cleaned_path, index=False)
